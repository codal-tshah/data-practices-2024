# %% [markdown]
# <a href="https://colab.research.google.com/github/codal-tshah/data-practices/blob/10_apr/pandas/Pandas_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # **Comparison with SQL**

# %%
import pandas as pd
import numpy as np

# %%
url = (
    "https://raw.githubusercontent.com/pandas-dev"
    "/pandas/main/pandas/tests/io/data/csv/tips.csv"
)

tips = pd.read_csv(url)
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips[["total_bill","tip","smoker","time"]]
# Out:
#      total_bill   tip smoker    time
# 0         16.99  1.01     No  Dinner
# 1         10.34  1.66     No  Dinner
# 2         21.01  3.50     No  Dinner
# 3         23.68  3.31     No  Dinner
# 4         24.59  3.61     No  Dinner
# ..          ...   ...    ...     ...
# 239       29.03  5.92     No  Dinner
# 240       27.18  2.00    Yes  Dinner
# 241       22.67  2.00    Yes  Dinner
# 242       17.82  1.75     No  Dinner
# 243       18.78  3.00     No  Dinner
#
# [244 rows x 4 columns]

# %% [markdown]
# **DataFrame.assign() method of a DataFrame to append a new column**

# %%
tips.assign(tip_rate = tips["tip"] / tips["total_bill"])

# old method
# tips["tip_rate"] = tips["tip"]/tips["total_bill"]
# tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_rate
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.059447
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.160542
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.166587
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.139780
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.146808
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.159744
#
# [244 rows x 8 columns]

# %%
tips["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
tips[tips["size"]==6]
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 125       29.80  4.2  Female     No  Thur   Lunch     6
# 141       34.30  6.7    Male     No  Thur   Lunch     6
# 143       27.05  5.0  Female     No  Thur   Lunch     6
# 156       48.17  5.0    Male     No   Sun  Dinner     6

# %%
is_dinner = tips["time"] == "Dinner"
is_dinner
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 239    True
# 240    True
# 241    True
# 242    True
# 243    True
# Name: time, Length: 244, dtype: bool

# %%
is_dinner.value_counts()
# Out:
# time
# True     176
# False     68
# Name: count, dtype: int64

# %%
sort_by_tip = tips.sort_values("tip")
sort_by_totalbill = tips.sort_values("total_bill", ascending=False)
combine = {
    "tip": sort_by_tip,
    "total_bill" : sort_by_totalbill
}
combine
# Out:
# {'tip':      total_bill    tip     sex smoker   day    time  size
#  67         3.07   1.00  Female    Yes   Sat  Dinner     1
#  236       12.60   1.00    Male    Yes   Sat  Dinner     2
#  92         5.75   1.00  Female    Yes   Fri  Dinner     2
#  111        7.25   1.00  Female     No   Sat  Dinner     1
#  0         16.99   1.01  Female     No   Sun  Dinner     2
#  ..          ...    ...     ...    ...   ...     ...   ...
#  141       34.30   6.70    Male     No  Thur   Lunch     6
#  59        48.27   6.73    Male     No   Sat  Dinner     4
#  23        39.42   7.58    Male     No   Sat  Dinner     4
#  212       48.33   9.00    Male     No   Sat  Dinner     4
#  170       50.81  10.00    Male    Yes   Sat  Dinner     3
#
#  [244 rows x 7 columns],
#  'total_bill':      total_bill    tip     sex smoker   day    time  size
#  170       50.81  10.00    Male    Yes   Sat  Dinner     3
#  212       48.33   9.00    Male     No   Sat  Dinner     4
#  59        48.27   6.73    Male     No   Sat  Dinner     4
#  156       48.17   5.00    Male     No   Sun  Dinner     6
#  182       45.35   3.50    Male    Yes   Sun  Dinner     3
#  ..          ...    ...     ...    ...   ...     ...   ...
#  149        7.51   2.00    Male     No  Thur   Lunch     2
#  111        7.25   1.00  Female     No   Sat  Dinner     1
#  172        7.25   5.15    Male    Yes   Sun  Dinner     2
#  92         5.75   1.00  Female    Yes   Fri  Dinner     2
#  67         3.07   1.00  Female    Yes   Sat  Dinner     1
#
#  [244 rows x 7 columns]}

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips[(tips["sex"]=="Female") & (tips["smoker"]=="Yes") & (tips["tip"]>4)]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2
# 191       19.81  4.19  Female    Yes  Thur   Lunch     2
# 197       43.11  5.00  Female    Yes  Thur   Lunch     4
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3

# %%
# tips["smoker"].isna().unique()
tips["smoker"].notna()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 239    True
# 240    True
# 241    True
# 242    True
# 243    True
# Name: smoker, Length: 244, dtype: bool

# %%
frame = pd.DataFrame(
    {
        "col1" : ["A","B","C",np.nan,"F","H"],
        "col2" : [1,8,np.nan,89,2,0]
    }
)
frame
# Out:
#   col1  col2
# 0    A   1.0
# 1    B   8.0
# 2    C   NaN
# 3  NaN  89.0
# 4    F   2.0
# 5    H   0.0

# %%
frame["col2"].isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# Name: col2, dtype: bool

# %%
tips.groupby("sex").size()
# Out:
# sex
# Female     87
# Male      157
# dtype: int64

# %%
tips.groupby("sex").count()
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# Female          87   87      87   87    87    87
# Male           157  157     157  157   157   157

# %%
tips.groupby("day").agg({"tip":"mean","day":"size" })
# Out:
#            tip  day
# day
# Fri   2.734737   19
# Sat   2.993103   87
# Sun   3.255132   76
# Thur  2.771452   62

# %%
tips.groupby("day").agg({"tip":"mean" , "total_bill":"mean"})
# Out:
#            tip  total_bill
# day
# Fri   2.734737   17.151579
# Sat   2.993103   20.441379
# Sun   3.255132   21.410000
# Thur  2.771452   17.682742

# %%
tips.groupby(["day","sex"]).agg({"tip":"mean" , "total_bill":"mean"})
# Out:
#                   tip  total_bill
# day  sex
# Fri  Female  2.781111   14.145556
#      Male    2.693000   19.857000
# Sat  Female  2.801786   19.680357
#      Male    3.083898   20.802542
# Sun  Female  3.367222   19.872222
#      Male    3.220345   21.887241
# Thur Female  2.575625   16.715312
#      Male    2.980333   18.714667

# %%
tips.groupby(["day","sex"]).agg({"tip":["size","mean"] , "total_bill":"mean"})
# Out:
#              tip           total_bill
#             size      mean       mean
# day  sex
# Fri  Female    9  2.781111  14.145556
#      Male     10  2.693000  19.857000
# Sat  Female   28  2.801786  19.680357
#      Male     59  3.083898  20.802542
# Sun  Female   18  3.367222  19.872222
#      Male     58  3.220345  21.887241
# Thur Female   32  2.575625  16.715312
#      Male     30  2.980333  18.714667

# %% [markdown]
# # **JOIN**

# %%
df1 = pd.DataFrame({"key": ["A", "B", "C", "D"], "value": np.random.randn(4)})
df2 = pd.DataFrame({"key": ["B", "D", "E", "D"], "value": np.random.randn(4)})

# %% [markdown]
# merge performs an INNER JOIN by default

# %%
pd.merge(df1,df2,on="key")
# Out:
#   key   value_x   value_y
# 0   B -0.636464  0.685027
# 1   D  0.875100  1.764559
# 2   D  0.875100 -0.769200

# %%
indexed_df2 = df2.set_index("key")
pd.merge(df1, indexed_df2, left_on="key", right_index=True)
# Out:
#   key   value_x   value_y
# 1   B -0.636464  0.685027
# 3   D  0.875100  1.764559
# 3   D  0.875100 -0.769200

# %%
pd.merge(df1,df2,on="key",how="left")
# Out:
#   key   value_x   value_y
# 0   A -0.232272       NaN
# 1   B -0.636464  0.685027
# 2   C  2.271736       NaN
# 3   D  0.875100  1.764559
# 4   D  0.875100 -0.769200

# %%
pd.merge(df1,df2,on="key",how="right")
# Out:
#   key   value_x   value_y
# 0   B -0.636464  0.685027
# 1   D  0.875100  1.764559
# 2   E       NaN -1.899329
# 3   D  0.875100 -0.769200

# %%
pd.merge(df1,df2,on="key",how="outer")
# Out:
#   key   value_x   value_y
# 0   A -0.232272       NaN
# 1   B -0.636464  0.685027
# 2   C  2.271736       NaN
# 3   D  0.875100  1.764559
# 4   D  0.875100 -0.769200
# 5   E       NaN -1.899329

# %% [markdown]
# UNION

# %% [markdown]
# UNION ALL can be performed using concat()

# %%
pd.concat([df1,df2])
# Out:
#   key     value
# 0   A -0.232272
# 1   B -0.636464
# 2   C  2.271736
# 3   D  0.875100
# 0   B  0.685027
# 1   D  1.764559
# 2   E -1.899329
# 3   D -0.769200

# %%
pd.concat([df1,df2]).drop_duplicates()
# Out:
#   key     value
# 0   A -0.232272
# 1   B -0.636464
# 2   C  2.271736
# 3   D  0.875100
# 0   B  0.685027
# 1   D  1.764559
# 2   E -1.899329
# 3   D -0.769200

# %%
df2.head(2)
# Out:
#   key     value
# 0   B  0.685027
# 1   D  1.764559

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.nlargest(15, columns="tip").tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 47        32.40  6.00    Male     No   Sun  Dinner     4
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 88        24.71  5.85    Male     No  Thur   Lunch     2
# 181       23.33  5.65    Male    Yes   Sun  Dinner     2
# 44        30.40  5.60    Male     No   Sun  Dinner     4
# 52        34.81  5.20  Female     No   Sun  Dinner     4
# 85        34.83  5.17  Female     No  Thur   Lunch     4
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4

# %%
tips.nlargest(10 + 5, columns="tip").tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 47        32.40  6.00    Male     No   Sun  Dinner     4
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 88        24.71  5.85    Male     No  Thur   Lunch     2
# 181       23.33  5.65    Male    Yes   Sun  Dinner     2
# 44        30.40  5.60    Male     No   Sun  Dinner     4
# 52        34.81  5.20  Female     No   Sun  Dinner     4
# 85        34.83  5.17  Female     No  Thur   Lunch     4
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4

# %%
(
    tips.assign(
        rnk=tips.groupby(["day"])["total_bill"].rank(
            method="first", ascending=False
        )
    )
    .query("rnk < 3")
    .sort_values(["day", "rnk"])
)
# Out:
#      total_bill    tip     sex smoker   day    time  size  rnk
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4  1.0
# 90        28.97   3.00    Male    Yes   Fri  Dinner     2  2.0
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3  1.0
# 212       48.33   9.00    Male     No   Sat  Dinner     4  2.0
# 156       48.17   5.00    Male     No   Sun  Dinner     6  1.0
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3  2.0
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4  1.0
# 142       41.19   5.00    Male     No  Thur   Lunch     5  2.0

# %% [markdown]
# UPdate

# %%
tips.loc[tips["tip"] < 2, "tip"] *= 2
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  2.02  Female     No   Sun  Dinner     2
# 1         10.34  3.32    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  3.50    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips = tips.loc[tips["tip"] <= 9]
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  2.02  Female     No   Sun  Dinner     2
# 1         10.34  3.32    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  3.50    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 7 columns]

# %%
filtered_tips = tips[tips["tip"] > 9]
print(filtered_tips)
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

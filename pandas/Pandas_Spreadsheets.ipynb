# %% [markdown]
# <a href="https://colab.research.google.com/github/codal-tshah/data-practices/blob/10_apr/pandas/Pandas_Spreadsheets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Comparison with spreadsheets**

# %%
import pandas as pd
import numpy as np

# %%
url = (
    "https://raw.githubusercontent.com/pandas-dev"
    "/pandas/main/pandas/tests/io/data/csv/tips.csv"
)
tips = pd.read_csv(url)
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips = pd.read_csv(url)
tips.head()

# alternatively, read_table is an alias to read_csv with tab delimiter
# tips = pd.read_table("tips.csv", header=None)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.to_excel("/content/drive/MyDrive/data_practices/pandas/data/tips.xlsx")

# %%
# Read the Excel file
tips_df = pd.read_excel("/content/drive/MyDrive/data_practices/pandas/data/tips.xlsx")

# Display the first few rows of the DataFrame
print(tips_df.head())
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["total_bill"] = tips["total_bill"] - 2

tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         10.99  1.01  Female     No   Sun  Dinner     2
# 1          4.34  1.66    Male     No   Sun  Dinner     3
# 2         15.01  3.50    Male     No   Sun  Dinner     3
# 3         17.68  3.31    Male     No   Sun  Dinner     2
# 4         18.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       23.03  5.92    Male     No   Sat  Dinner     3
# 240       21.18  2.00  Female    Yes   Sat  Dinner     2
# 241       16.67  2.00    Male    Yes   Sat  Dinner     2
# 242       11.82  1.75    Male     No   Sat  Dinner     2
# 243       12.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips["new_bill"] = tips["total_bill"] / 2
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  new_bill
# 0         10.99  1.01  Female     No   Sun  Dinner     2     5.495
# 1          4.34  1.66    Male     No   Sun  Dinner     3     2.170
# 2         15.01  3.50    Male     No   Sun  Dinner     3     7.505
# 3         17.68  3.31    Male     No   Sun  Dinner     2     8.840
# 4         18.59  3.61  Female     No   Sun  Dinner     4     9.295
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       23.03  5.92    Male     No   Sat  Dinner     3    11.515
# 240       21.18  2.00  Female    Yes   Sat  Dinner     2    10.590
# 241       16.67  2.00    Male    Yes   Sat  Dinner     2     8.335
# 242       11.82  1.75    Male     No   Sat  Dinner     2     5.910
# 243       12.78  3.00  Female     No  Thur  Dinner     2     6.390
#
# [244 rows x 8 columns]

# %%
tips = tips.drop("new_bill",axis=1)

# %%
tips[tips["total_bill"] > 10]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         10.99  1.01  Female     No   Sun  Dinner     2
# 2         15.01  3.50    Male     No   Sun  Dinner     3
# 3         17.68  3.31    Male     No   Sun  Dinner     2
# 4         18.59  3.61  Female     No   Sun  Dinner     4
# 5         19.29  4.71    Male     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       23.03  5.92    Male     No   Sat  Dinner     3
# 240       21.18  2.00  Female    Yes   Sat  Dinner     2
# 241       16.67  2.00    Male    Yes   Sat  Dinner     2
# 242       11.82  1.75    Male     No   Sat  Dinner     2
# 243       12.78  3.00  Female     No  Thur  Dinner     2
#
# [148 rows x 7 columns]

# %%
is_dinner = tips["time"] == "Dinner"
is_dinner
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 239    True
# 240    True
# 241    True
# 242    True
# 243    True
# Name: time, Length: 244, dtype: bool

# %%
tips["bucket"] = np.where(tips["total_bill"] < 10,"low", "high")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size bucket
# 0         10.99  1.01  Female     No   Sun  Dinner     2   high
# 1          4.34  1.66    Male     No   Sun  Dinner     3    low
# 2         15.01  3.50    Male     No   Sun  Dinner     3   high
# 3         17.68  3.31    Male     No   Sun  Dinner     2   high
# 4         18.59  3.61  Female     No   Sun  Dinner     4   high
# ..          ...   ...     ...    ...   ...     ...   ...    ...
# 239       23.03  5.92    Male     No   Sat  Dinner     3   high
# 240       21.18  2.00  Female    Yes   Sat  Dinner     2   high
# 241       16.67  2.00    Male    Yes   Sat  Dinner     2   high
# 242       11.82  1.75    Male     No   Sat  Dinner     2   high
# 243       12.78  3.00  Female     No  Thur  Dinner     2   high
#
# [244 rows x 8 columns]

# %%
tips[["sex", "total_bill", "tip"]]
# Out:
#         sex  total_bill   tip
# 0    Female       10.99  1.01
# 1      Male        4.34  1.66
# 2      Male       15.01  3.50
# 3      Male       17.68  3.31
# 4    Female       18.59  3.61
# ..      ...         ...   ...
# 239    Male       23.03  5.92
# 240  Female       21.18  2.00
# 241    Male       16.67  2.00
# 242    Male       11.82  1.75
# 243  Female       12.78  3.00
#
# [244 rows x 3 columns]

# %%
tips["date1"] = pd.Timestamp("2013-01-15")

tips["date2"] = pd.Timestamp("2015-02-15")

tips["date1_year"] = tips["date1"].dt.year

tips["date2_month"] = tips["date2"].dt.month

tips["months_between"] = tips["date2"].dt.to_period("M") - tips["date1"].dt.to_period("M")


tips[
    ["date1", "date2", "date1_year", "date2_month",  "months_between"]
]
# Out:
#          date1      date2  date1_year  date2_month    months_between
# 0   2013-01-15 2015-02-15        2013            2  <25 * MonthEnds>
# 1   2013-01-15 2015-02-15        2013            2  <25 * MonthEnds>
# 2   2013-01-15 2015-02-15        2013            2  <25 * MonthEnds>
# 3   2013-01-15 2015-02-15        2013            2  <25 * MonthEnds>
# 4   2013-01-15 2015-02-15        2013            2  <25 * MonthEnds>
# ..         ...        ...         ...          ...               ...
# 239 2013-01-15 2015-02-15        2013            2  <25 * MonthEnds>
# 240 2013-01-15 2015-02-15        2013            2  <25 * MonthEnds>
# 241 2013-01-15 2015-02-15        2013            2  <25 * MonthEnds>
# 242 2013-01-15 2015-02-15        2013            2  <25 * MonthEnds>
# 243 2013-01-15 2015-02-15        2013            2  <25 * MonthEnds>
#
# [244 rows x 5 columns]

# %%
tips.rename(columns={"total_bill": "total_bill_2"})
# Out:
#      total_bill_2   tip     sex smoker   day    time  size bucket      date1  \
# 0           10.99  1.01  Female     No   Sun  Dinner     2   high 2013-01-15
# 1            4.34  1.66    Male     No   Sun  Dinner     3    low 2013-01-15
# 2           15.01  3.50    Male     No   Sun  Dinner     3   high 2013-01-15
# 3           17.68  3.31    Male     No   Sun  Dinner     2   high 2013-01-15
# 4           18.59  3.61  Female     No   Sun  Dinner     4   high 2013-01-15
# ..            ...   ...     ...    ...   ...     ...   ...    ...        ...
# 239         23.03  5.92    Male     No   Sat  Dinner     3   high 2013-01-15
# 240         21.18  2.00  Female    Yes   Sat  Dinner     2   high 2013-01-15
# 241         16.67  2.00    Male    Yes   Sat  Dinner     2   high 2013-01-15
# 242         11.82  1.75    Male     No   Sat  Dinner     2   high 2013-01-15
# 243         12.78  3.00  Female     No  Thur  Dinner     2   high 2013-01-15
#
#          date2  date1_year  date2_month    months_between
# 0   2015-02-15        2013            2  <25 * MonthEnds>
# 1   2015-02-15        2013            2  <25 * MonthEnds>
# 2   2015-02-15        2013            2  <25 * MonthEnds>
# 3   2015-02-15        2013            2  <25 * MonthEnds>
# 4   2015-02-15        2013            2  <25 * MonthEnds>
# ..         ...         ...          ...               ...
# 239 2015-02-15        2013            2  <25 * MonthEnds>
# 240 2015-02-15        2013            2  <25 * MonthEnds>
# 241 2015-02-15        2013            2  <25 * MonthEnds>
# 242 2015-02-15        2013            2  <25 * MonthEnds>
# 243 2015-02-15        2013            2  <25 * MonthEnds>
#
# [244 rows x 13 columns]

# %%
tips = tips.sort_values(["sex", "total_bill"])
tips.head(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size bucket      date1  \
# 67        -2.93  1.00  Female    Yes   Sat  Dinner     1    low 2013-01-15
# 92        -0.25  1.00  Female    Yes   Fri  Dinner     2    low 2013-01-15
# 111        1.25  1.00  Female     No   Sat  Dinner     1    low 2013-01-15
# 145        2.35  1.50  Female     No  Thur   Lunch     2    low 2013-01-15
# 135        2.51  1.25  Female     No  Thur   Lunch     2    low 2013-01-15
# 178        3.60  4.00  Female    Yes   Sun  Dinner     2    low 2013-01-15
# 82         4.07  1.83  Female     No  Thur   Lunch     1    low 2013-01-15
# 226        4.09  2.00  Female    Yes   Fri   Lunch     2    low 2013-01-15
# 51         4.29  2.60  Female     No   Sun  Dinner     2    low 2013-01-15
# 136        4.33  2.00  Female     No  Thur   Lunch     2    low 2013-01-15
#
#          date2  date1_year  date2_month    months_between
# 67  2015-02-15        2013            2  <25 * MonthEnds>
# 92  2015-02-15        2013            2  <25 * MonthEnds>
# 111 2015-02-15        2013            2  <25 * MonthEnds>
# 145 2015-02-15        2013            2  <25 * MonthEnds>
# 135 2015-02-15        2013            2  <25 * MonthEnds>
# 178 2015-02-15        2013            2  <25 * MonthEnds>
# 82  2015-02-15        2013            2  <25 * MonthEnds>
# 226 2015-02-15        2013            2  <25 * MonthEnds>
# 51  2015-02-15        2013            2  <25 * MonthEnds>
# 136 2015-02-15        2013            2  <25 * MonthEnds>

# %%
tips["time"].str.len()
# Out:
# 67     6
# 92     6
# 111    6
# 145    5
# 135    5
#       ..
# 182    6
# 156    6
# 59     6
# 212    6
# 170    6
# Name: time, Length: 244, dtype: int64

# %%
tips["sex"].str.find("ale")
# Out:
# 67     3
# 92     3
# 111    3
# 145    3
# 135    3
#       ..
# 182    1
# 156    1
# 59     1
# 212    1
# 170    1
# Name: sex, Length: 244, dtype: int64

# %%
tips["sex"].str[0:1]
# Out:
# 67     F
# 92     F
# 111    F
# 145    F
# 135    F
#       ..
# 182    M
# 156    M
# 59     M
# 212    M
# 170    M
# Name: sex, Length: 244, dtype: object

# %%
firstlast = pd.DataFrame({"String": ["John Smith", "Jane Cook"]})

firstlast["First_Name"] = firstlast["String"].str.split(" ")[0]

firstlast["Last_Name"] = firstlast["String"].str.rsplit(" ")[1]

firstlast
# Out:
#        String First_Name Last_Name
# 0  John Smith       John      Jane
# 1   Jane Cook      Smith      Cook

# %%
df = pd.DataFrame({"AAA": [1] * 8, "BBB": list(range(0, 8))})
df
# Out:
#    AAA  BBB
# 0    1    0
# 1    1    1
# 2    1    2
# 3    1    3
# 4    1    4
# 5    1    5
# 6    1    6
# 7    1    7

# %%
df = pd.DataFrame({"AAA": [1] * 8, "BBB":np.random.rand(8)})
df
# Out:
#    AAA       BBB
# 0    1  0.928089
# 1    1  0.281488
# 2    1  0.561397
# 3    1  0.054169
# 4    1  0.751319
# 5    1  0.354192
# 6    1  0.761611
# 7    1  0.149548

# %%
df = pd.DataFrame({"AAA": [1] * 8, "BBB":np.random.randint(80,size=8)})
df
# Out:
#    AAA  BBB
# 0    1   28
# 1    1   12
# 2    1   36
# 3    1   69
# 4    1   11
# 5    1    3
# 6    1    1
# 7    1    9

# %%
series = list(range(1,5))
series
# Out:
# [1, 2, 3, 4]

# %%
df.loc[2:5,"AAA"] = series
df
# Out:
#    AAA  BBB
# 0    1   28
# 1    1   12
# 2    1   36
# 3    2   69
# 4    3   11
# 5    4    3
# 6    1    1
# 7    1    9

# %%
df = pd.DataFrame(
    {
        "class": ["A", "A", "A", "B", "C", "D"],
        "student_count": [42, 35, 42, 50, 47, 45],
        "all_pass": ["Yes", "Yes", "Yes", "No", "No", "Yes"],
    }
)

df
# Out:
#   class  student_count all_pass
# 0     A             42      Yes
# 1     A             35      Yes
# 2     A             42      Yes
# 3     B             50       No
# 4     C             47       No
# 5     D             45      Yes

# %%
df.drop_duplicates()
# Out:
#   class  student_count all_pass
# 0     A             42      Yes
# 1     A             35      Yes
# 3     B             50       No
# 4     C             47       No
# 5     D             45      Yes

# %%
pd.pivot_table(
    tips, values="tip", index=["size"], columns=["sex"], aggfunc=np.average
)
# Out:
# sex     Female      Male
# size
# 1     1.276667  1.920000
# 2     2.528448  2.614184
# 3     3.250000  3.476667
# 4     4.021111  4.172143
# 5     5.140000  3.750000
# 6     4.600000  5.850000

# %%
tips
# Out:
#      total_bill    tip     sex smoker   day    time  size bucket      date1  \
# 67        -2.93   1.00  Female    Yes   Sat  Dinner     1    low 2013-01-15
# 92        -0.25   1.00  Female    Yes   Fri  Dinner     2    low 2013-01-15
# 111        1.25   1.00  Female     No   Sat  Dinner     1    low 2013-01-15
# 145        2.35   1.50  Female     No  Thur   Lunch     2    low 2013-01-15
# 135        2.51   1.25  Female     No  Thur   Lunch     2    low 2013-01-15
# ..          ...    ...     ...    ...   ...     ...   ...    ...        ...
# 182       39.35   3.50    Male    Yes   Sun  Dinner     3   high 2013-01-15
# 156       42.17   5.00    Male     No   Sun  Dinner     6   high 2013-01-15
# 59        42.27   6.73    Male     No   Sat  Dinner     4   high 2013-01-15
# 212       42.33   9.00    Male     No   Sat  Dinner     4   high 2013-01-15
# 170       44.81  10.00    Male    Yes   Sat  Dinner     3   high 2013-01-15
#
#          date2  date1_year  date2_month    months_between
# 67  2015-02-15        2013            2  <25 * MonthEnds>
# 92  2015-02-15        2013            2  <25 * MonthEnds>
# 111 2015-02-15        2013            2  <25 * MonthEnds>
# 145 2015-02-15        2013            2  <25 * MonthEnds>
# 135 2015-02-15        2013            2  <25 * MonthEnds>
# ..         ...         ...          ...               ...
# 182 2015-02-15        2013            2  <25 * MonthEnds>
# 156 2015-02-15        2013            2  <25 * MonthEnds>
# 59  2015-02-15        2013            2  <25 * MonthEnds>
# 212 2015-02-15        2013            2  <25 * MonthEnds>
# 170 2015-02-15        2013            2  <25 * MonthEnds>
#
# [244 rows x 13 columns]

# %%
tips == "sun"
# Out:
#      total_bill    tip    sex  smoker    day   time   size  bucket  date1  \
# 67        False  False  False   False  False  False  False   False  False
# 92        False  False  False   False  False  False  False   False  False
# 111       False  False  False   False  False  False  False   False  False
# 145       False  False  False   False  False  False  False   False  False
# 135       False  False  False   False  False  False  False   False  False
# ..          ...    ...    ...     ...    ...    ...    ...     ...    ...
# 182       False  False  False   False  False  False  False   False  False
# 156       False  False  False   False  False  False  False   False  False
# 59        False  False  False   False  False  False  False   False  False
# 212       False  False  False   False  False  False  False   False  False
# 170       False  False  False   False  False  False  False   False  False
#
#      date2  date1_year  date2_month  months_between
# 67   False       False        False           False
# 92   False       False        False           False
# 111  False       False        False           False
# 145  False       False        False           False
# 135  False       False        False           False
# ..     ...         ...          ...             ...
# 182  False       False        False           False
# 156  False       False        False           False
# 59   False       False        False           False
# 212  False       False        False           False
# 170  False       False        False           False
#
# [244 rows x 13 columns]

# %%
tips["day"].str.contains("S")
# Out:
# 67      True
# 92     False
# 111     True
# 145    False
# 135    False
#        ...
# 182     True
# 156     True
# 59      True
# 212     True
# 170     True
# Name: day, Length: 244, dtype: bool

# %%
tips.replace("Thu", "Thursday")
# Out:
#      total_bill    tip     sex smoker   day    time  size bucket      date1  \
# 67        -2.93   1.00  Female    Yes   Sat  Dinner     1    low 2013-01-15
# 92        -0.25   1.00  Female    Yes   Fri  Dinner     2    low 2013-01-15
# 111        1.25   1.00  Female     No   Sat  Dinner     1    low 2013-01-15
# 145        2.35   1.50  Female     No  Thur   Lunch     2    low 2013-01-15
# 135        2.51   1.25  Female     No  Thur   Lunch     2    low 2013-01-15
# ..          ...    ...     ...    ...   ...     ...   ...    ...        ...
# 182       39.35   3.50    Male    Yes   Sun  Dinner     3   high 2013-01-15
# 156       42.17   5.00    Male     No   Sun  Dinner     6   high 2013-01-15
# 59        42.27   6.73    Male     No   Sat  Dinner     4   high 2013-01-15
# 212       42.33   9.00    Male     No   Sat  Dinner     4   high 2013-01-15
# 170       44.81  10.00    Male    Yes   Sat  Dinner     3   high 2013-01-15
#
#          date2  date1_year  date2_month    months_between
# 67  2015-02-15        2013            2  <25 * MonthEnds>
# 92  2015-02-15        2013            2  <25 * MonthEnds>
# 111 2015-02-15        2013            2  <25 * MonthEnds>
# 145 2015-02-15        2013            2  <25 * MonthEnds>
# 135 2015-02-15        2013            2  <25 * MonthEnds>
# ..         ...         ...          ...               ...
# 182 2015-02-15        2013            2  <25 * MonthEnds>
# 156 2015-02-15        2013            2  <25 * MonthEnds>
# 59  2015-02-15        2013            2  <25 * MonthEnds>
# 212 2015-02-15        2013            2  <25 * MonthEnds>
# 170 2015-02-15        2013            2  <25 * MonthEnds>
#
# [244 rows x 13 columns]
